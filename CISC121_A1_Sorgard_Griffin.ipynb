# %% [markdown]
# <a href="https://colab.research.google.com/github/monekenke/CISC121-Colab-Documents/blob/main/CISC121_A1_Sorgard_Griffin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <details>
#   <summary> </summary>
#   This is a university assignment, there are expilicit instructions for the use of AI, please follow them. For any departure from what is instructred, this assignment cannot be accepted.
# </details>

# %% [markdown]
# 1. Your Name: Griffin Sorgard
# 2. Section: 002
# 3. ID: 20548238
# 4. Github Link of this notebook:
# 5. Chat: *Referenced in the notebook where used*

# %% [markdown]
# # **CISC 121 - Section 002 – Assignment 1** 🚀
# ## Total of 25 marks to be converted to 5% of grade
#
#
# ## 🔗 Problem
# 1. Two Sum: https://leetcode.com/problems/two-sum/
#
# 2. Divisor Game: https://leetcode.com/problems/divisor-game/
#
# 3. Longest Common Prefix: https://leetcode.com/problems/longest-common-prefix/
#
# 4. Move Zeroes: https://leetcode.com/problems/move-zeroes/
#
# 5. Add Digits: https://leetcode.com/problems/add-digits/
#
# ## 5 Marks per problem (1 mark per subsection of the problem)

# %% [markdown]
# #  Problem 1

# %% [markdown]
# ## 1. Understanding & Breakdown
#
# ### _Understand the problem, using the pillars of Computation: Problem Decomposition, Pattern Recognition, Abstraction, and Algortihmic Thinking. For algorithmic thinking explain the inputs/outputs, constraints, and write down your plan or steps to solve the problem or draw the flowchart using digital or real pen-paper. Insert the image below._
#
# **AI Level 1** is allowed to understand the concept, but you need to sketch the problem down by yourself (Check the Syllabus for more details about AI use levels).
#
# **Your effort is more important than the accuracy for this section**
#
# Use the following markdown to provide your answer

# %% [markdown]
# The easiest way to solve this problem would be to add each and every number in the nums array to eachother and check the resulting sum with your target. While it may not be optimal, it could find your solution.
#
# In my opinion, brute forcing is a great way to start solving a problem, as it allows you to get an answer before going back and optimizing to get the best solution.

# %% [markdown]
# ![tm1.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# **Review Guidance:**
#
# Visit the **"Solutions"** tab on LeetCode (the provided link above) for the selected problem and review at least one top-rated solution. You may also search for relevant discussions or Q&A threads on **Stack Overflow** or other forums to understand how others approached the problem.
#
# Then, write your own version based on what you understood. The goal is not to copy but to apply what you learned. Always include links to the resources you reviewed.
#
# ---
#
# ### **Example Answer (for "Two Sum"):**
#
# "I reviewed the top solution under the LeetCode “Solutions” tab and one post on Stack Overflow:  https://stackoverflow.com/questions/30021060/two-sum-on-leetcode. At first the syntax was confusing, but the idea is clearer now: we build a dictionary mapping each number to its index. Then, as we loop with enumerate, we check if the target number minus the value is already in the dictionary and make sure it’s not the same index. If yes, that means we’ve found the pair, so we return both indices (shifted by +1 for 1-based indexing)."

# %%
# Your draft code here (does not need to be fully correct)
class Solution(object):
  def twoSum(self, nums, target):
    n = len(nums)
    for i in range(n):
      for j in range(i + 1, n):
        if nums[i] + nums[j] == target:
          return [i, j]

# %% [markdown]
# I reviewed a newer solution that was more in-tune with my original brute forcing idea called "Using Nested For Loops and If Conditions". While the solution was written in Java, the syntax was easy to understand. Essentially, you need to loop through every pair (i, j), and check if adding the two numbers in those indices is the same as your target number.

# %% [markdown]
# ## 3. Final Correct Code
#
# _This version must pass all required test cases and handle edge cases correctly._
#
# At this stage, you may:
# - Use reviewed solutions or programming AI tools (e.g., ChatGPT, GitHub Copilot) to refine and fix errors.
# - Refactor your draft to ensure accuracy and completeness.
#
#  **AI Level 4 is allowed**, but you **must include a disclaimer** that clearly states what tools you used, how you used them, and for which part of the code.

# %%
# Final working solution

# example inputs
nums = [2, 7, 11, 15]
target = 9

# solution class
class Solution(object):
  def twoSum(self, nums, target):
    for i in range(len(nums)):
      for j in range(i + 1, len(nums)):
        if nums[i] + nums[j] == target:
          return [i, j]

# instance of solution
solver = Solution()

result = solver.twoSum(nums, target)
print(result)
# Out:
# [0, 1]

# %% [markdown]
# Add the screenshot of output for all the test cases from your working solutions.
# ![image.png](data:image/png;base64,...)
#
# I used the same inputs as the 3 leetcode examples, so the outputs are [1,2] and [0,1] respectively, which matches the leetcode solution. (I also used this before the len(num) change, which is why it matches the draft

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# Fix 1: added test compatibility

# Draft version: didn't handle testing, outputting nothing.

# Fixed version: takes the input for both nums and target, and spits an output as needed.

# %%
# Fix 2: small simplification to the code by removing the "n = len(nums)"

# Draft version: works perfectly fine.


# Fixed version: works the same, but is 1 line shorter, potentially increasing readability.

# %% [markdown]
# ## 5. Reflection on Your Contribution
# _Where did AI or Other's code helped or fail to help? What specific logic or debugging did you contribute yourself?_
#
# ## Example
# 1. I used ChatGPT (Level 4) to help identify an edge case where my draft code failed when the input string started with a closing bracket. I also used ChatGPT to help structure the final loop and mapping dictionary, but verified all logic myself by tracing the code.
#
# 2.  I used ChatGPT to help write the loop. But the code had an indentation error after the `if` block, which caused it to fail. I fixed the spacing and made sure the code runs correctly.
#
# 3. I used opensource code from Github. I found and fixed a logic bug where they used if s[i] == '(' or ')', which always returned True. I corrected it to properly check both conditions.

# %% [markdown]
# ## Your answer:

# %% [markdown]
# 1. I was able to use another Leetcode user's solution to find my own, as she followed the same brute forcing (simple) approach that I did. Her code was in Java, but it provided a general format and good basis to start solving off of.

# %% [markdown]
# #  Problem 2

# %% [markdown]
# ## 1. Understanding & Breakdown
#
# ### _Understand the problem, using the pillars of Computation: Problem Decomposition, Pattern Recognition, Abstraction, and Algortihmic Thinking. For algorithmic thinking explain the inputs/outputs, constraints, and write down your plan or steps to solve the problem or draw the flowchart using digital or real pen-paper. Insert the image below._
#
# **AI Level 1** is allowed to understand the concept, but you need to sketch the problem down by yourself (Check the Syllabus for more details about AI use levels).
#
# **Your effort is more important than the accuracy for this section**
#
# Use the following markdown to provide your answer

# %% [markdown]
# After breaking down the problem and analysing smaller number inputs, I discovered an important pattern that makes the whole problem easier: an even n value results in alice always winning, while an odd n value results in bob winning, which reduces the whole problem to checking the nature of n. Ultimately, the plan involves reading the input of n, if even, return true, otherwise return false.

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# **Review Guidance:**
#
# Visit the **"Solutions"** tab on LeetCode (the provided link above) for the selected problem and review at least one top-rated solution. You may also search for relevant discussions or Q&A threads on **Stack Overflow** or other forums to understand how others approached the problem.
#
# Then, write your own version based on what you understood. The goal is not to copy but to apply what you learned. Always include links to the resources you reviewed.
#
# ---
#
# ### **Example Answer (for "Two Sum"):**
#
# "I reviewed the top solution under the LeetCode “Solutions” tab and one post on Stack Overflow:  https://stackoverflow.com/questions/30021060/two-sum-on-leetcode. At first the syntax was confusing, but the idea is clearer now: we build a dictionary mapping each number to its index. Then, as we loop with enumerate, we check if the target number minus the value is already in the dictionary and make sure it’s not the same index. If yes, that means we’ve found the pair, so we return both indices (shifted by +1 for 1-based indexing)."

# %%
# Your draft code here (does not need to be fully correct)
class Solution(object):
  def divisorGame(self, n):
      return n % 2 == 0

# %% [markdown]
# I looked at the solutions tab on LeetCode, and found out that other people had found the simple pattern to find the solution.

# %% [markdown]
# ## 3. Final Correct Code
#
# _This version must pass all required test cases and handle edge cases correctly._
#
# At this stage, you may:
# - Use reviewed solutions or programming AI tools (e.g., ChatGPT, GitHub Copilot) to refine and fix errors.
# - Refactor your draft to ensure accuracy and completeness.
#
#  **AI Level 4 is allowed**, but you **must include a disclaimer** that clearly states what tools you used, how you used them, and for which part of the code.

# %%
# Final working solution
class Solution(object):
  def divisorGame(self, n):
      return n % 2 == 0

# instance of the solution class
sol = Solution()

# test case
n = 22
print(sol.divisorGame(n))
# Out:
# True

# %% [markdown]
# Add the screenshot of output for all the test cases from your working solutions.

# %% [markdown]
# I feel like a screenshot is too much here, it throws true if n is even and odd if odd. Pretty self-explanatory.

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# Fix 1: Added support for test cases

# Draft version: Only had the logic, and didn't display results to the user.

# Fixed version: Added an instance for the Solution class, and gave the instance a fixed n input before printing the result.

# %%
# Fix 2: N/A (I didn't do anything else)

# Draft version: N/A


# Fixed version: N/A

# %% [markdown]
# ## 5. Reflection on Your Contribution
# _Where did AI or Other's code helped or fail to help? What specific logic or debugging did you contribute yourself?_
#
# ## Example
# 1. I used ChatGPT (Level 4) to help identify an edge case where my draft code failed when the input string started with a closing bracket. I also used ChatGPT to help structure the final loop and mapping dictionary, but verified all logic myself by tracing the code.
#
# 2.  I used ChatGPT to help write the loop. But the code had an indentation error after the `if` block, which caused it to fail. I fixed the spacing and made sure the code runs correctly.
#
# 3. I used opensource code from Github. I found and fixed a logic bug where they used if s[i] == '(' or ')', which always returned True. I corrected it to properly check both conditions.

# %% [markdown]
# ## Your answer:
#
# 1. I broke down the code and realized the whole even/odd solution. This approach seemed too easy, but I checked my results to the solutions page and realized that the easy solution was in fact true. (I specifically saw the solution titled: "[Java/C++/Python] return N % 2 == 0")

# %% [markdown]
# #  Problem 3

# %% [markdown]
# ## 1. Understanding & Breakdown
#
# ### _Understand the problem, using the pillars of Computation: Problem Decomposition, Pattern Recognition, Abstraction, and Algortihmic Thinking. For algorithmic thinking explain the inputs/outputs, constraints, and write down your plan or steps to solve the problem or draw the flowchart using digital or real pen-paper. Insert the image below._
#
# **AI Level 1** is allowed to understand the concept, but you need to sketch the problem down by yourself (Check the Syllabus for more details about AI use levels).
#
# **Your effort is more important than the accuracy for this section**
#
# Use the following markdown to provide your answer

# %% [markdown]
# While I understood this problem pretty easily, I was confused on how to go about solving it. After deconstructing the problem,

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# **Review Guidance:**
#
# Visit the **"Solutions"** tab on LeetCode (the provided link above) for the selected problem and review at least one top-rated solution. You may also search for relevant discussions or Q&A threads on **Stack Overflow** or other forums to understand how others approached the problem.
#
# Then, write your own version based on what you understood. The goal is not to copy but to apply what you learned. Always include links to the resources you reviewed.
#
# ---
#
# ### **Example Answer (for "Two Sum"):**
#
# "I reviewed the top solution under the LeetCode “Solutions” tab and one post on Stack Overflow:  https://stackoverflow.com/questions/30021060/two-sum-on-leetcode. At first the syntax was confusing, but the idea is clearer now: we build a dictionary mapping each number to its index. Then, as we loop with enumerate, we check if the target number minus the value is already in the dictionary and make sure it’s not the same index. If yes, that means we’ve found the pair, so we return both indices (shifted by +1 for 1-based indexing)."

# %%
# Your draft code here (does not need to be fully correct)
class Solution(object):
  def longestCommonPrefix(self, strs):
    prefix = strs[0]
    for i in range(1, len(strs)):
      while strs[i].find(prefix) != 0:
        prefix = prefix[:-1]
    return prefix

# %% [markdown]
# I reviewed one of the top solutions on leetcode. This solution took a different approach and the syntax was somewhat confusing, but the solution this person took was to start with the first word as the maximum possible prefix, and then to gradually shorten the word until a prefix was found. If no prefix is found, it returns "".

# %% [markdown]
# ## 3. Final Correct Code
#
# _This version must pass all required test cases and handle edge cases correctly._
#
# At this stage, you may:
# - Use reviewed solutions or programming AI tools (e.g., ChatGPT, GitHub Copilot) to refine and fix errors.
# - Refactor your draft to ensure accuracy and completeness.
#
#  **AI Level 4 is allowed**, but you **must include a disclaimer** that clearly states what tools you used, how you used them, and for which part of the code.

# %%
# Final working solution
# AI DISCLAIMER: I made a mistake with the indentation, so I asked ChatGPT the following: "this program: [code] threw this error: [error], how can i fix this?"
class Solution(object):
    def longestCommonPrefix(self, strs):
        if not strs: # if there are no strings, it auto-returns nothing
            return ""
        prefix = strs[0] # set the prefix to the first word in the array
        for i in range(1, len(strs)): # iterates through characters in the word
            while strs[i].find(prefix) != 0:
                prefix = prefix[:-1] # shortens the prefix by one character from the end
                if not prefix: # if prefix is empty, return ""
                  return ""
        return prefix

# test cases
sol = Solution()
strs = ["reckless", "imagine", "rectify"]
print(sol.longestCommonPrefix(strs))

# %% [markdown]
# Add the screenshot of output for all the test cases from your working solutions.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# Fix 1: added "fail protection"

# Draft version: the original was likely to either not work or throw an error if either there was not prefix, or if there were no strings in the array.

# Fixed version: added both if not strs: and if not prefix: to handle these cases, ensuring no unnecessary errors are thrown.

# %%
# Fix 2: added test cases and commnenting

# Draft version: the draft only had the logic, and would likely be confusing for someone who wasn't familiar with the problem.


# Fixed version: commenting for readability, and code to handle testing, clearly displaying the output to the user in the same way the problem wanted.

# %% [markdown]
# ## 5. Reflection on Your Contribution
# _Where did AI or Other's code helped or fail to help? What specific logic or debugging did you contribute yourself?_
#
# ## Example
# 1. I used ChatGPT (Level 4) to help identify an edge case where my draft code failed when the input string started with a closing bracket. I also used ChatGPT to help structure the final loop and mapping dictionary, but verified all logic myself by tracing the code.
#
# 2.  I used ChatGPT to help write the loop. But the code had an indentation error after the `if` block, which caused it to fail. I fixed the spacing and made sure the code runs correctly.
#
# 3. I used opensource code from Github. I found and fixed a logic bug where they used if s[i] == '(' or ')', which always returned True. I corrected it to properly check both conditions.

# %% [markdown]
# ## Your answer:
#
# 1. I wasn't paying attention to my indentation, and I ended up getting errors with my test code. I used ChatGPT to point out the error, and I fixed it accordingly.
# 2. When trying to find out a way to remove letters at the end of the prefix string, I originally took a long approach that involved getting the length of the string and taking 1 off of it to get the last character, before realizing that there was a builtin way to do this, using the [:-1] method. I got this off of the solution code I looked at, and it saved the code a lot of readability.

# %% [markdown]
# #  Problem 4

# %% [markdown]
# ## 1. Understanding & Breakdown
#
# ### _Understand the problem, using the pillars of Computation: Problem Decomposition, Pattern Recognition, Abstraction, and Algortihmic Thinking. For algorithmic thinking explain the inputs/outputs, constraints, and write down your plan or steps to solve the problem or draw the flowchart using digital or real pen-paper. Insert the image below._
#
# **AI Level 1** is allowed to understand the concept, but you need to sketch the problem down by yourself (Check the Syllabus for more details about AI use levels).
#
# **Your effort is more important than the accuracy for this section**
#
# Use the following markdown to provide your answer

# %% [markdown]
# After deconstructing the problem, I found out that the concept is somewhat simple, involving an array that needs to have the numbers moved forwards while keeping the zeroes at the end. This splits the problem in two: 1. is to figure out how to find and shift any non-zero numbers to the front. 2. to fill in the remaining positions with zeroes. The input is the integer array nums, and the output is the "sorted" array, non-copied. To do this, we need to have a position variable that increments every time a non-zero number is discovered. When a non-zero number is found, it will be shifted to the position indicated by the position variable, before incrementing said variable and moving on.

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# **Review Guidance:**
#
# Visit the **"Solutions"** tab on LeetCode (the provided link above) for the selected problem and review at least one top-rated solution. You may also search for relevant discussions or Q&A threads on **Stack Overflow** or other forums to understand how others approached the problem.
#
# Then, write your own version based on what you understood. The goal is not to copy but to apply what you learned. Always include links to the resources you reviewed.
#
# ---
#
# ### **Example Answer (for "Two Sum"):**
#
# "I reviewed the top solution under the LeetCode “Solutions” tab and one post on Stack Overflow:  https://stackoverflow.com/questions/30021060/two-sum-on-leetcode. At first the syntax was confusing, but the idea is clearer now: we build a dictionary mapping each number to its index. Then, as we loop with enumerate, we check if the target number minus the value is already in the dictionary and make sure it’s not the same index. If yes, that means we’ve found the pair, so we return both indices (shifted by +1 for 1-based indexing)."

# %%
# Your draft code here (does not need to be fully correct)
class Solution(object):
  def moveZeroes(self, nums):
    pos = 0
    for i in range(len(nums)):
      if nums[i] != 0:
        nums[pos] = nums[i]
        pos += 1
    for i in range(pos, len(nums)):
      nums[i] = 0
    return nums

# %% [markdown]
# I looked at one of the top solutions called the "Two Pointer Approach" and it seemed to be almost the same as my deconstruction. The goal as explained by the solution: "We want to shift all non-zero elements to the front of the array, keeping their relative order, and move all zeroes to the end. This can be done using a two-pointer technique—one pointer to iterate through the array (i), and another (j) to track the position of the next non-zero element." I found this to be nearly the same as my solution so I used this as an example.

# %% [markdown]
# ## 3. Final Correct Code
#
# _This version must pass all required test cases and handle edge cases correctly._
#
# At this stage, you may:
# - Use reviewed solutions or programming AI tools (e.g., ChatGPT, GitHub Copilot) to refine and fix errors.
# - Refactor your draft to ensure accuracy and completeness.
#
#  **AI Level 4 is allowed**, but you **must include a disclaimer** that clearly states what tools you used, how you used them, and for which part of the code.

# %%
# Final working solution
# [AI Disclaimer example: Used ChatGPT with prompt “How to handle recursion base case” only for concept]
class Solution(object):
  def moveZeroes(self, nums):
    pos = 0 # position variable
    for i in range(len(nums)):
      if nums[i] != 0:
        nums[pos] = nums[i] # move non-zero numbers to the pos spot
        pos += 1            # change to the next available position
    for i in range(pos, len(nums)):
      nums[i] = 0 # pass again, replacing all values after pos with zeroes
    return nums

# test code
sol = Solution()
nums = [0, 0, 3, 54, 1, 0, 4, 0]
print(sol.moveZeroes(nums))
# Out:
# [3, 54, 1, 4, 0, 0, 0, 0]

# %% [markdown]
# Add the screenshot of output for all the test cases from your working solutions.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# Fix 1: Commenting

# Draft version: While straightforward, it may be hard to read for a non-coder or someone not familiar with the problem.

# Fixed version: I commenting spots that I deemed useful, to make it easier to read.

# %%
# Fix 2: Test Cases

# Draft version: Only the logic was coded, and it didn't actually throw anything.


# Fixed version: I added support for test cases, and the output is clearly given to the user as the problem wanted.

# %% [markdown]
# ## 5. Reflection on Your Contribution
# _Where did AI or Other's code helped or fail to help? What specific logic or debugging did you contribute yourself?_
#
# ## Example
# 1. I used ChatGPT (Level 4) to help identify an edge case where my draft code failed when the input string started with a closing bracket. I also used ChatGPT to help structure the final loop and mapping dictionary, but verified all logic myself by tracing the code.
#
# 2.  I used ChatGPT to help write the loop. But the code had an indentation error after the `if` block, which caused it to fail. I fixed the spacing and made sure the code runs correctly.
#
# 3. I used opensource code from Github. I found and fixed a logic bug where they used if s[i] == '(' or ')', which always returned True. I corrected it to properly check both conditions.

# %% [markdown]
# ## Your answer:
#
# 1. Checking the solutions tab on Leetcode was useful as it showed that my logic was correct, and that plenty of other people took the same approach as me.
#
# 2. I forgot the syntax for the range() operator, specifically the first parameter, so I looked at the python documentation to see how it works. (shown in the: for i in range(*pos*, len(nums)):, the pos variable in italics)

# %% [markdown]
# #  Problem 5

# %% [markdown]
# ## 1. Understanding & Breakdown
#
# ### _Understand the problem, using the pillars of Computation: Problem Decomposition, Pattern Recognition, Abstraction, and Algortihmic Thinking. For algorithmic thinking explain the inputs/outputs, constraints, and write down your plan or steps to solve the problem or draw the flowchart using digital or real pen-paper. Insert the image below._
#
# **AI Level 1** is allowed to understand the concept, but you need to sketch the problem down by yourself (Check the Syllabus for more details about AI use levels).
#
# **Your effort is more important than the accuracy for this section**
#
# Use the following markdown to provide your answer

# %% [markdown]
# This problem involves taking an integer input num, and "breaking it down" to get only one digit. This breaking down is done by splitting the number into it's individual digits, adding the new digits and repeating until only 1 digit remains. To do this, I came up with the following steps to solve:
# 1. split the number into its respective digits
# 2. add those digits into a new number
# 3. check the new number to see if it is a single digit, if yes, return the digit. if no, go back to step 1. and repeat
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# **Review Guidance:**
#
# Visit the **"Solutions"** tab on LeetCode (the provided link above) for the selected problem and review at least one top-rated solution. You may also search for relevant discussions or Q&A threads on **Stack Overflow** or other forums to understand how others approached the problem.
#
# Then, write your own version based on what you understood. The goal is not to copy but to apply what you learned. Always include links to the resources you reviewed.
#
# ---
#
# ### **Example Answer (for "Two Sum"):**
#
# "I reviewed the top solution under the LeetCode “Solutions” tab and one post on Stack Overflow:  https://stackoverflow.com/questions/30021060/two-sum-on-leetcode. At first the syntax was confusing, but the idea is clearer now: we build a dictionary mapping each number to its index. Then, as we loop with enumerate, we check if the target number minus the value is already in the dictionary and make sure it’s not the same index. If yes, that means we’ve found the pair, so we return both indices (shifted by +1 for 1-based indexing)."

# %%
# Your draft code here (does not need to be fully correct)
class Solution(object):
  def addDigits(self, num):
    if num < 10:
      return num
    digits = [int(digit) for digit in str(num)]
    num = sum(digits)
    return self.addDigits(num)

# %% [markdown]
# For this code, I implemented my idea of splitting the input num into its respective digits, before adding them and repeating the steps until it reaches 1 digit. My code also has a failsafe for if the input is already 1 digit. After looking at the solutions tab, I found that other people had the same idea as me, and to get the code for splitting the number into digits i used this thread: https://stackoverflow.com/questions/21270320/turn-a-single-number-into-single-digits-python

# %% [markdown]
# ## 3. Final Correct Code
#
# _This version must pass all required test cases and handle edge cases correctly._
#
# At this stage, you may:
# - Use reviewed solutions or programming AI tools (e.g., ChatGPT, GitHub Copilot) to refine and fix errors.
# - Refactor your draft to ensure accuracy and completeness.
#
#  **AI Level 4 is allowed**, but you **must include a disclaimer** that clearly states what tools you used, how you used them, and for which part of the code.

# %%
# Final working solution
# [AI Disclaimer example: used ChatGPT with prompt: Is there an easier or more efficient way of programming this? Here is the code I've made, which works: [draft code above]]

# ChatGPT gave me the most simple approach, which is known as the "Digital Root"
class Solution(object):
  def addDigits(self, num):
    if num == 0:
      return 0
    if num % 9 == 0:
      return 9
    return num % 9

# test cases
solution = Solution()
print(solution.addDigits(38))  # output: 2
print(solution.addDigits(0))  # output: 0
# Out:
# 2
# 0

# %% [markdown]
# Add the screenshot of output for all the test cases from your working solutions.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# Fix 1: entirely new approach

# Draft version: followed what i believe to be the most logical approach if the digital root solution isn't known

# Fixed version: uses the digital root approach, which whittles down the code to merely 7 lines

# %%
# Fix 2: ChatGPT originally used a conditional, which I am not familiar with, so I expanded the code to fit the format I'm more used to.

# Draft version: used conditionals, and was much shorter.


# Fixed version: longer code, but uses a format I am more used to, as well as a format that is easier to read for someone who might not be familiar with the digital root approach

# %% [markdown]
# ## 5. Reflection on Your Contribution
# _Where did AI or Other's code helped or fail to help? What specific logic or debugging did you contribute yourself?_
#
# ## Example
# 1. I used ChatGPT (Level 4) to help identify an edge case where my draft code failed when the input string started with a closing bracket. I also used ChatGPT to help structure the final loop and mapping dictionary, but verified all logic myself by tracing the code.
#
# 2.  I used ChatGPT to help write the loop. But the code had an indentation error after the `if` block, which caused it to fail. I fixed the spacing and made sure the code runs correctly.
#
# 3. I used opensource code from Github. I found and fixed a logic bug where they used if s[i] == '(' or ')', which always returned True. I corrected it to properly check both conditions.

# %% [markdown]
# ## Your answer:
# 1. using ChatGPT, I found that there was a much easier and simpler approach to solving the problem, as the entire problem can be simplified into the simple operation *num % 9*, which is far shorter than the number-splitting approach I took at first.
# 2. To make sure I was doing it correctly, I used a thread from stackoverflow to get the easiest code logic for splitting a number into digits, which works just fine.

# %% [markdown]
# #  Repeat this template for Problems 2–5
# You may copy-paste the above section 4 more times or duplicate cells in your notebook environment.
#
# Remember:
# Proper attribution
# No copy-pasting from AI or others

# %% [markdown]
# 1. Your Name:
# 2. Section:
# 3. ID:
# 4. Github Link of this notebook:
# 5. Chat
#
# *   Share Chat in a shared Document link
# *   if you used Colab's built in Gemini, copy paste full chat below

# %% [markdown]
# # **The most important part of writing code is not the code itself, but the thinking that leads to it. Thank You 😀**
